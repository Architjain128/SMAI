# %% [markdown]
# # Assignment 2 - Question 1
# The objective of this assignment is to get you familiarize with  the  problem  of  `Clustering`.
#
# ## Instructions
# - Write your code and analysis in the indicated cells.
# - Ensure that this notebook runs without errors when the cells are run in sequence.
# - Do not attempt to change the contents of other cells.
# - No inbuilt functions to be used until specified
#
# ## Submission
# - Ensure that this notebook runs without errors when the cells are run in sequence.
# - Rename the notebook to `<roll_number>_Assignment2_Q1.ipynb`.

# %%
import nltk
nltk.download('punkt')
# if u r facing issues while importing nltk, please uncomment above line and run
import re
import numpy as np
import time
import math
import pickle
import sklearn
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import silhouette_score as ss
from scipy.cluster.hierarchy import dendrogram
from sklearn.decomposition import PCA
# Out:
# [nltk_data] Downloading package punkt to /home/archit/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# !pip3 install sentence-transformers
from sentence_transformers import SentenceTransformer
# Out:
# Requirement already satisfied: sentence-transformers in /home/archit/.local/lib/python3.8/site-packages (2.1.0)
# Requirement already satisfied: scipy in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (1.7.1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (4.12.3)
# Requirement already satisfied: scikit-learn in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (0.24.2)
# Requirement already satisfied: tokenizers>=0.10.3 in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (0.10.3)
# Requirement already satisfied: huggingface-hub in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (0.1.2)
# Requirement already satisfied: torchvision in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (0.11.1)
# Requirement already satisfied: tqdm in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (4.62.3)
# Requirement already satisfied: nltk in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (3.6.2)
# Requirement already satisfied: numpy in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (1.21.3)
# Requirement already satisfied: torch>=1.6.0 in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (1.10.0)
# Requirement already satisfied: sentencepiece in /home/archit/.local/lib/python3.8/site-packages (from sentence-transformers) (0.1.96)
# Requirement already satisfied: requests in /home/archit/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: sacremoses in /home/archit/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.46)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (5.3.1)
# Requirement already satisfied: filelock in /home/archit/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (3.3.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/archit/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.8.21)
# Requirement already satisfied: packaging>=20.0 in /home/archit/.local/lib/python3.8/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (21.0)
# Requirement already satisfied: joblib>=0.11 in /home/archit/.local/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/archit/.local/lib/python3.8/site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/archit/.local/lib/python3.8/site-packages (from huggingface-hub->sentence-transformers) (3.10.0.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /home/archit/.local/lib/python3.8/site-packages (from torchvision->sentence-transformers) (8.3.1)
# Requirement already satisfied: click in /home/archit/.local/lib/python3.8/site-packages (from nltk->sentence-transformers) (7.1.2)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /home/archit/.local/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/archit/.local/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /home/archit/.local/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/archit/.local/lib/python3.8/site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers) (2021.10.8)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/archit/.local/lib/python3.8/site-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers) (2.4.7)
# 2022-02-21 19:02:39.200760: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-21 19:02:39.201236: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Dataset
#
#
#
# *   Try to explore the dataset and first understand
# *   Steps while processing the dataset:
#
# 1.   Load the dataset
# >> The 20 newsgroups dataset comprises around 18000 newsgroups posts on 20 topics split in two subsets: train and test. Here, we only use train part of the dataset as we don't need any training.
#
# 2.   pre-processing of the dataset
# >>   A set of basic pre-processing steps are given below, if you can do it better, it is appreciable
# 3.   Trying to obtain the embeddings for the text.
# >> Here, we used bert model to obtain the embeddings, if you want to use anyother sentence/word embeddings (ELMo,universal sentence encoder, or other bert models) you can use it, but not mandatorily change it)
#
# PS: You need not completely understand how bert works. If you are interested, few links will be mentioned below.

# %%
# loading of dataset

from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train')

# print(list(newsgroups_train))
#['data', 'filenames', 'target_names', 'target', 'DESCR']
# all we require for our task is data and target. 
#target_names describe the different groups present (which are 20) all over the dataset

# print(list(newsgroups_train.target_names))

# %%
bert_model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
#preprocessing of sentences and the article

def remove_punct(text):
  text = re.sub('[^a-zA-Z0-9 ]+','', text)
  return text

def remove_urls(text):
  url_pattern = re.compile(r'https?://\S+|www\.\S+')
  return url_pattern.sub(r'', text)

def remove_tag(text):
  text=' '.join(text)
  html_pattern = re.compile('<.*?>')
  return html_pattern.sub(r'', text)

def pre_process_sentence(sentence):
  sentence = sentence.lower()
  sentence = remove_punct(remove_urls(sentence))
  return sentence

def pre_process_article(article):
  article = str(article).replace("\n", ' ')
  article = sent_tokenize(article)
  sentences = []
  for each in article:
    if len(each.split(":")) > 1:
      continue
    sentences.append(pre_process_sentence(each))
  return sentences

# %%
def get_review_embedding(article):
  sentences = pre_process_article(article)

  #here review(input) has to be a list of sentences
  #use suitable embeddings to get an embedding for the whole review
  #usage of sentence embeddings is recommended

  sentence_embeddings = bert_model.encode(sentences)

  # take average of all sentence embeddings to obtain a review embedding 
  review_embedding = np.zeros(768)
  for each in sentence_embeddings:
    review_embedding = np.add(np.array(each), review_embedding)
  if len(sentence_embeddings) > 0:
    review_embedding = np.divide(review_embedding, len(sentence_embeddings))
  
  return review_embedding

# %%
X=[]
start = time.time()
for i in range(len(newsgroups_train.data)):
    if i%1000 == 0:
        print(i,time.time()-start)
        start=time.time()
    X.append(get_review_embedding(newsgroups_train.data[i]))
X=np.array(X)

fpca=PCA(n_components=2)
fpca.fit(X)
pca=fpca.transform(X)

# import pickle
# with open("./bert.pkl","wb") as f:
#     pickle.dump(X,f)
# with open("./bert_pca.pkl","wb") as f:
#     pickle.dump(pca,f)

# %%
# can find pkl file at https://iiitaphyd-my.sharepoint.com/:f:/g/personal/archit_jain_students_iiit_ac_in/EjQq9f1xwZhKoRFmQnLQJ8MB643NkXjwVRZZ4ZT4YhhEMg?e=knz1AM

# X=np.array(pickle.load(open('bert.pkl','rb')))
# pca=pickle.load(open('bert_pca.pkl','rb'))
# fpca=PCA(n_components=2)
# fpca.fit(X)
# pca=fpca.transform(X)

# %%
# data visualization 

# Try to visualise the points from all the domains and try to visualise them 
# hint: you can use PCA 

import sklearn
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import random
import numpy as np

# %% [markdown]
# # K_Means Algorithm

# %%
# code to write your Kmeans algorithm
#implement your KMeans algorithm here, and visualise the clusters obtained 

from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=4).fit(X)
a=kmeans.labels_

# %% [markdown]
# #### My inbuilt but not used

# %%
def random_unique_k_centroid(x,k):
    n=x.shape[0]
    idx=set()
    while len(idx)<k:
        idx.add(np.random.randint(0,n))
    return x[list(idx)]

def dis_euclidean(x,y):
    val=0.0
    for i in range(len(x)):
        val+=(x[i]-y[i])**2
    return math.sqrt(val)

def dis_from_all_centroid(x,centroids):
    val=[]
    for i in range(len(centroids)):
        val.append(dis_euclidean(x,centroids[i]))
    return val

def form_clusters(x,centroids):
    k=len(centroids)
    clusters={}
    for i in range(k):
        clusters[i]=[]
    for i in range(len(x)):
        dis=dis_from_all_centroid(x[i],centroids)
        idx=np.argmin(dis)
        clusters[idx].append(x[i])
    return clusters

# %%
k=2
seeds=random_unique_k_centroid(np.array(X),k)
clusters = form_clusters(X,seeds)

# %% [markdown]
# #### Using kmeans

# %%
def visualisation(k,X,pca,vis=True):
    kmeans = KMeans(n_clusters=k, random_state=4).fit(X)
    a=kmeans.labels_
    interia=kmeans.inertia_
    dic={}
    for i in range(len(a)):
        if a[i] not in dic:
            dic[a[i]]=[]
        dic[a[i]].append(pca[i])
    if vis==True:
        for i in dic:
            x=np.array(dic[i]).T
            plt.scatter(x[0],x[1])
        plt.title("Kmeans Visualisation using PCA k="+str(k))
        plt.show()
    return a,interia

# %% [markdown]
# ##### Plots

# %%
for i in range(2,10):
    visualisation(i,X,pca)

# %% [markdown]
# # Elbow method
#
#
#
# *   Try to understand how elbow method works
# *   Plot the graph between average distance and the number of clusters
# *   Use elbow method to find the optimal number of clusters,

# %% [markdown]
# Elbow method uses inertia which is the sum of squared distances of samples to their closest cluster center to finding out best k for clustering and to determine the optimal number of clusters, we have to select the value of k at the `elbow` in the point after which the inertia start decreasing in a linear fashion

# %%
def elbow_method():
    inertia=[]
    for i in range(2,10):
        _,b=visualisation(i,X,pca,False)
        inertia.append(b)
    plt.plot(range(2,10),inertia)
    plt.title("Elbow Method")
    plt.show()

elbow_method()

# %% [markdown]
# #### Optimal number of cluster(k) value is 5

# %% [markdown]
# # Silhouette Method
#
#
# *   Compute silhouette score varying the K number of clusters
#
# *   Plot the graph between silhoutte score and number of clusters
#
# *   Find the optimal number of clusters using silhouette method
#
#
#
#
# > Report the optimal number of clusters you obtained from above two methods (elbow and silhouette)

# %%
def silhouette_score():
    sil=[]
    for i in range(2,10):
        a,_=visualisation(i,X,pca,False)
        sil.append(ss(X,a,metric='euclidean',sample_size=1000,random_state=4))
    plt.plot(range(2,10),sil)
    plt.title("Silhouette Method")
    plt.show()

silhouette_score()

# %% [markdown]
# #### Optimal number of cluster(k) value is 2 and than 4

# %% [markdown]
# # Agglomerative clustering

# %%
# code to write your Kmeans algorithm
#implement your KMeans algorithm here, and visualise the clusters obtained 

from sklearn.cluster import AgglomerativeClustering

def visual_AgglomerativeClustering():
    clustering = AgglomerativeClustering().fit(X)
    a=clustering.labels_
    dic={}
    for i in range(len(a)):
        if a[i] not in dic:
            dic[a[i]]=[]
        dic[a[i]].append(pca[i])
    for i in dic:
        x=np.array(dic[i]).T
        plt.scatter(x[0],x[1])
    plt.title("Agglomerative Clustering Visualisation using PCA")
    plt.show()
    return a

labels  = visual_AgglomerativeClustering()

# %% [markdown]
# # Dendogram
#
#
# *   Try to understand the difference between agglomerative clustering and Divisive clustering
# *   Plot dendograms for both kinds of clustering
# *   Find the optimal number of clusters with the help of Dendogram

# %% [markdown]
# #### Agglomerative clustering vs Divisive clustering
#
# + Agglomerative clustering is bottom-up approach, whereas Divisive clustering is  top-down approach.
#
# + Agglomerative clustering treats each data as a singleton cluster at the outset and then successively agglomerates pairs of clusters until all clusters have been merged into a single cluster that contains all data.
#
# + Divisive clustering requires a method for splitting a cluster that contains the whole data and proceeds by splitting clusters recursively until individual data have been split into singleton clusters.
#
# + Agglomerative clustering makes decisions by considering the local patterns or neighbor points without initially taking into account the global distribution of data, whereas divisive clustering takes into consideration the global distribution of data when making top-level partitioning decisions.
#
# + A divisive algorithm is also more accurate.

# %%
def plot_dendrogram(model,p=5):
    counts = np.zeros(model.children_.shape[0])
    n_samples = len(model.labels_)
    for i, merge in enumerate(model.children_):
        current_count = 0
        for child_idx in merge:
            if child_idx < n_samples:
                current_count += 1
            else:
                current_count += counts[child_idx - n_samples]
        counts[i] = current_count
    linkage_matrix = np.column_stack([model.children_, model.distances_, counts]).astype(float)
    dendrogram(linkage_matrix,truncate_mode='level',p=p)

# %%
# code to write dendogram
def denogram_AgglomerativeClustering(p=5):
    clustering = AgglomerativeClustering(distance_threshold=0, n_clusters=None).fit(X)
    plt.title("Dendrogram")
    plot_dendrogram(clustering,p)
    plt.show()

denogram_AgglomerativeClustering()

# %% [markdown]
# Observing this dendogram i think we can easily divide the cluster in 2 parts but if we need more we can seaprate it more to get 4
# each of haveing minimum distance of 150 between them and as we decrease the distance more clusters comes into picture
#
# |distance|#of cluster|
# |---|---|
# |250|2|
# |150|4|
# |100|7|

# %% [markdown]
# # useful links to understand BERT
#
# *  https://towardsdatascience.com/bert-explained-state-of-the-art-language-model-for-nlp-f8b21a9b6270#:~:text=How%20BERT%20works,%2Dwords)%20in%20a%20text.&text=As%20opposed%20to%20directional%20models,sequence%20of%20words%20at%20once.
